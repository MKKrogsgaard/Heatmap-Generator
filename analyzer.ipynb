# %%
from garmin_fit_sdk import Decoder, Stream

# %%
stream = Stream.from_file("data\HM3.fit")
decoder = Decoder(stream)

print(f"is_fit: {decoder.is_fit()}")
decoder.check_integrity()
# Out:
# is_fit: True
